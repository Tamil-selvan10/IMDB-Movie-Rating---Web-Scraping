# %%
import requests # to make HTTP requests
from bs4 import BeautifulSoup # to pull data out of HTML file

# %%
url='https://www.imdb.com/search/title/?groups=top_250'

# %%
response=requests.get(url)
response
# Out:
# <Response [200]>

# %%
imdb_html=BeautifulSoup(response.text,'html.parser')

# %%
bigboxes=imdb_html.find_all('div',{'class':'lister-item mode-advanced'})

# %%
len(bigboxes)
# Out:
# 50

# %%
bigbox=bigboxes[0].find_all('div',{'class':'lister-item-content'})

# %% [markdown]
# #### Section 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
bigbox[0].find_all('h3',{'class':'lister-item-header'})[0]
# Out:
# <h3 class="lister-item-header">
# <span class="lister-item-index unbold text-primary">1.</span>
# <a href="/title/tt15398776/">Oppenheimer</a>
# <span class="lister-item-year text-muted unbold">(2023)</span>
# </h3>

# %%
bigbox[0].find_all('h3',{'class':'lister-item-header'})[0].find_all('span')[0].text.replace('.','')
# Out:
# '1'

# %%
bigbox[0].find_all('h3',{'class':'lister-item-header'})[0].find_all('a')[0].text
# Out:
# 'Oppenheimer'

# %%
bigbox[0].find_all('h3',{'class':'lister-item-header'})[0].find_all('span')[1].text.replace('(','').replace(')','')
# Out:
# '2023'

# %% [markdown]
# #### Section 2

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
bigbox[0].find_all('p')[0]
# Out:
# <p class="text-muted">
# <span class="certificate">R</span>
# <span class="ghost">|</span>
# <span class="runtime">180 min</span>
# <span class="ghost">|</span>
# <span class="genre">
# Biography, Drama, History            </span>
# </p>

# %%
bigbox[0].find_all('p')[0].find_all('span',{'class':'certificate'})[0].text
# Out:
# 'R'

# %%
bigbox[0].find_all('p')[0].find('span',{'class':'runtime'}).text # find & find_all
# Out:
# '180 min'

# %%
bigbox[0].find_all('p')[0].find('span',{'class':'runtime'}).text.replace(' min','')
# Out:
# '180'

# %%
bigbox[0].find_all('p')[0].find('span',{'class':'genre'}).text.replace('\n','').replace(' ','')
# Out:
# 'Biography,Drama,History'

# %% [markdown]
# #### section 3

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
bigbox[0].find_all('div',{'class':'ratings-bar'})[0]
# Out:
# <div class="ratings-bar">
# <div class="inline-block ratings-imdb-rating" data-value="8.6" name="ir">
# <span class="global-sprite rating-star imdb-rating"></span>
# <strong>8.6</strong>
# </div>
# <div class="inline-block ratings-user-rating">
# <span class="userRatingValue" data-tconst="tt15398776" id="urv_tt15398776">
# <span class="global-sprite rating-star no-rating"></span>
# <span class="rate" data-no-rating="Rate this" data-value="0" name="ur">Rate this</span>
# </span>
# <div class="starBarWidget" id="sb_tt15398776">
# <div class="rating rating-list" data-csrf-token="" data-ga-identifier="" data-starbar-class="rating-list" data-user="" id="tt15398776|imdb|8.6|8.6|adv_li_tt||advsearch|title" itemprop="aggregateRating" itemscope="" itemtype="http://schema.org/AggregateRating" title="Users rated this 8.6/10 (418,504 votes) - click stars to rate">
# <meta content="8.6" itemprop="ratingValue"/>
# <meta content="10" itemprop="bestRating"/>
# ...

# %%
bigbox[0].find_all('div',{'class':'ratings-bar'})[0].div.strong.text
# Out:
# '8.6'

# %%
bigbox[0].find_all('div',{'class':'ratings-bar'})[0].find_all('div')[0].strong.text
# Out:
# '8.6'

# %%
bigbox[0].find_all('div',{'class':'ratings-bar'})[0].find_all('div',{'class':'inline-block ratings-metascore'})[0].span.text.replace(' ','')
# Out:
# '88'

# %%
bigbox[0].find_all('div',{'class':'ratings-bar'})[0].find_all('div')[4].span.text.replace(' ','')
# Out:
# '88'

# %% [markdown]
# #### section 4

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
bigbox[0].find_all('p')[1].text.replace('\n','')
# Out:
# 'The story of American scientist, J. Robert Oppenheimer, and his role in the development of the atomic bomb.'

# %% [markdown]
# ##### section 5

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
bigbox[0].find_all('p')
# Out:
# [<p class="text-muted">
#  <span class="certificate">R</span>
#  <span class="ghost">|</span>
#  <span class="runtime">180 min</span>
#  <span class="ghost">|</span>
#  <span class="genre">
#  Biography, Drama, History            </span>
#  </p>,
#  <p class="text-muted">
#  The story of American scientist, <a href="/name/nm0649185">J. Robert Oppenheimer</a>, and his role in the development of the atomic bomb.</p>,
#  <p class="">
#      Director:
#  <a href="/name/nm0634240/">Christopher Nolan</a>
#  <span class="ghost">|</span>
#      Stars:
#  <a href="/name/nm0614165/">Cillian Murphy</a>,
#  <a href="/name/nm1289434/">Emily Blunt</a>,
#  <a href="/name/nm0000354/">Matt Damon</a>,
#  <a href="/name/nm0000375/">Robert Downey Jr.</a>
#  </p>,
#  <p class="sort-num_votes-visible">
#  <span class="text-muted">Votes:</span>
#  <span data-value="418504" name="nv">418,504</span>
# ...

# %%
bigbox[0].find_all('p')[2].text.replace('\n','').replace(' ','').split(sep='|')
# Out:
# ['Director:ChristopherNolan',
#  'Stars:CillianMurphy,EmilyBlunt,MattDamon,RobertDowneyJr.']

# %%
bigbox[0].find_all('p')[2].text.replace('\n','').replace(' ','').split(sep='|')[0]
# Out:
# 'Director:ChristopherNolan'

# %%
bigbox[0].find_all('p')[2].text.replace('\n','').replace(' ','').split(sep='|')[0].split(sep=':')[1] #director
# Out:
# 'ChristopherNolan'

# %%
bigbox[0].find_all('p')[2].text.replace('\n','').replace(' ','').split(sep='|')[1]
# Out:
# 'Stars:CillianMurphy,EmilyBlunt,MattDamon,RobertDowneyJr.'

# %%
bigbox[0].find_all('p')[2].text.replace('\n','').replace(' ','').split(sep='|')[1].split(sep=':')[1] #stars
# Out:
# 'CillianMurphy,EmilyBlunt,MattDamon,RobertDowneyJr.'

# %% [markdown]
# ### section 6

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
bigbox[0].find_all('p')[3]
# Out:
# <p class="sort-num_votes-visible">
# <span class="text-muted">Votes:</span>
# <span data-value="418504" name="nv">418,504</span>
# <span class="ghost">|</span> <span class="text-muted top-chart-rank"><a href="https://www.imdb.com/chart/top/?ref_=ats_top250badge_intop250_to_top250chart">Top 250</a>:</span>
# <span data-value="39" name="nv">#39</span>
# </p>

# %%
bigbox[0].find_all('p')[3].find_all('span')
# Out:
# [<span class="text-muted">Votes:</span>,
#  <span data-value="418504" name="nv">418,504</span>,
#  <span class="ghost">|</span>,
#  <span class="text-muted top-chart-rank"><a href="https://www.imdb.com/chart/top/?ref_=ats_top250badge_intop250_to_top250chart">Top 250</a>:</span>,
#  <span data-value="39" name="nv">#39</span>]

# %%
bigbox[0].find_all('p')[3].find_all('span')[0].text
# Out:
# 'Votes:'

# %%
bigbox[0].find_all('p')[3].find_all('span')[1].text
# Out:
# '418,504'

# %%
bigbox[0].find_all('p')[3].find_all('span')[2].text
# Out:
# '|'

# %%
bigbox[0].find_all('p')[3].find_all('span')[3].text
# Out:
# 'Top 250:'

# %%
bigbox[0].find_all('p')[3].find_all('span')[4].text
# Out:
# '#39'

# %%
imdb_html
# Out:
# <!DOCTYPE html>
#
# <html xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <script type="text/javascript">var IMDbTimer={starttime: new Date().getTime(),pt:'java'};</script>
# <script>
#     if (typeof uet == 'function') {
#       uet("bb", "LoadTitle", {wb: 1});
#     }
# </script>
# <script>(function(t){ (t.events = t.events || {})["csm_head_pre_title"] = new Date().getTime(); })(IMDbTimer);</script>
# <title>IMDb "Top 250"
# (Sorted by Popularity Ascending) - IMDb</title>
# <script>(function(t){ (t.events = t.events || {})["csm_head_post_title"] = new Date().getTime(); })(IMDbTimer);</script>
# <script>
#     if (typeof uet == 'function') {
#       uet("be", "LoadTitle", {wb: 1});
#     }
# </script>
# <script>
#     if (typeof uex == 'function') {
#       uex("ld", "LoadTitle", {wb: 1});
#     }
# </script>
# <link href="https://www.imdb.com/search/title/?groups=top_250" rel="canonical"/>
# ...

# %%
imdb_html.find_all('div',{'class':'desc'})[0].find('a',{'class':'lister-page-next next-page'}).get('href')
# Out:
# '/search/title/?groups=top_250&start=51'

# %%
imdb_html.find_all('div',{'class':'desc'})[0].find_all('a',{'class':'lister-page-next next-page'})[0].get('href')
# Out:
# '/search/title/?groups=top_250&start=101'

# %%
url
# Out:
# 'https://www.imdb.com/search/title/?groups=top_250'

# %%
response=requests.get('https://www.imdb.com/search/title/?groups=top_250&start=101')

# %%
imdb_html=BeautifulSoup(response.content,'html.parser')

# %%
bigboxes=imdb_html.find_all('div',{'class':'lister-item mode-advanced'})

# %%
bigbox=bigboxes[4].find_all('div',{'class':'lister-item-content'})

# %%
bigbox
# Out:
# [<div class="lister-item-content">
#  <h3 class="lister-item-header">
#  <span class="lister-item-index unbold text-primary">105.</span>
#  <a href="/title/tt0091251/">Idi i smotri</a>
#  <span class="lister-item-year text-muted unbold">(1985)</span>
#  </h3>
#  <p class="text-muted">
#  <span class="certificate">A</span>
#  <span class="ghost">|</span>
#  <span class="runtime">142 min</span>
#  <span class="ghost">|</span>
#  <span class="genre">
#  Drama, Thriller, War            </span>
#  </p>
#  <div class="ratings-bar">
#  <div class="inline-block ratings-imdb-rating" data-value="8.4" name="ir">
#  <span class="global-sprite rating-star imdb-rating"></span>
#  <strong>8.4</strong>
#  </div>
#  <div class="inline-block ratings-user-rating">
#  <span class="userRatingValue" data-tconst="tt0091251" id="urv_tt0091251">
#  <span class="global-sprite rating-star no-rating"></span>
#  <span class="rate" data-no-rating="Rate this" data-value="0" name="ur">Rate this</span>
#  </span>
# ...

# %%
bigbox[0].find_all('div',{'class':'ratings-bar'})[0].find_all('div')[4].span.text.replace(' ','')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[273], line 1
# ----> 1 bigbox[0].find_all('div',{'class':'ratings-bar'})[0].find_all('div')[4].span.text.replace(' ','')
#
# IndexError: list index out of range

# %%
bigbox[0].find_all('div',{'class':'ratings-bar'})[0]
# Out:
# <div class="ratings-bar">
# <div class="inline-block ratings-imdb-rating" data-value="8.4" name="ir">
# <span class="global-sprite rating-star imdb-rating"></span>
# <strong>8.4</strong>
# </div>
# <div class="inline-block ratings-user-rating">
# <span class="userRatingValue" data-tconst="tt0091251" id="urv_tt0091251">
# <span class="global-sprite rating-star no-rating"></span>
# <span class="rate" data-no-rating="Rate this" data-value="0" name="ur">Rate this</span>
# </span>
# <div class="starBarWidget" id="sb_tt0091251">
# <div class="rating rating-list" data-csrf-token="" data-ga-identifier="" data-starbar-class="rating-list" data-user="" id="tt0091251|imdb|8.4|8.4|adv_li_tt||advsearch|title" itemprop="aggregateRating" itemscope="" itemtype="http://schema.org/AggregateRating" title="Users rated this 8.4/10 (89,555 votes) - click stars to rate">
# <meta content="8.4" itemprop="ratingValue"/>
# <meta content="10" itemprop="bestRating"/>
# ...
